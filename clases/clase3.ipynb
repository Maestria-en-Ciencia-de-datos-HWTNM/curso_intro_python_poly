# %% [markdown]
# # Clase 3 - Python Básico
# ## Diplomado en Argumentación y Narrativa Soportada en Análisis de Datos
# ### Politécnico Gran Colombiano - 2024
# <img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/Logo_del_Polit%C3%A9cnico_Grancolombiano.svg/1200px-Logo_del_Polit%C3%A9cnico_Grancolombiano.svg.png" width=300>

# %% [markdown]
# ## Pandas dataframe
# - Pandas es una librería(que contiene varios modulos e instrucciones) de Python especializada en el manejo y análisis de estructuras de datos.

# %%
#pip install pandas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('loan_data_set.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#!pip install openpyxl

# %%
file_name = 'SampleData.xlsx'
sheet = 'SalesOrders'

df_exl = pd.read_excel(io=file_name, sheet_name=sheet)
df_exl.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2021-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2021-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2021-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2021-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2021-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df_exl.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total'], dtype='object')

# %%
df.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status        date
# 609             1.0         Rural           Y  2021-03-16
# ...

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status        date
# 0             1.0         Urban           Y  2021-03-16
# ...

# %%
df.shape
# Out:
# (614, 14)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  date               614 non-null    object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 67.3+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.describe(exclude=np.number)
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status        date
# count            614         614         614
# unique             3           2           1
# top        Semiurban           Y  2021-03-16
# freq             233         422         614

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# date                  0
# dtype: int64

# %%
#‘bfill’, ‘ffill’, None, sin method: 0
#df.fillna(0,inplace=True)
#df.fillna(method='bfill',inplace=True)
#df['A'].fillna(df['A'].median(), inplace=True)
#formato de columnas
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# date                  0
# dtype: int64

# %%
#df.dropna(inplace=True) # eliminar filas con datos nulos
#df.dropna(axis=1, inplace=True) # #eliminar columnas con datos nulos
#df.drop("date",axis=1)  # eliminar columna 'date'

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  date               614 non-null    object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 67.3+ KB

# %%
df['Credit_History']=df['Credit_History'].astype('category')
df['ApplicantIncome']=df['ApplicantIncome'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int32
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    category
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  date               614 non-null    object
# dtypes: category(1), float64(3), int32(1), object(9)
# memory usage: 60.8+ KB

# %% [markdown]
# ## Seleccionar renglones
# #### loc[]  vs iloc[]
# - loc: acceder a través de su etiqueta
# - iloc: acceder a través de su posición

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#   Credit_History Property_Area Loan_Status        date
# 0            1.0         Urban           Y  2021-03-16
# ...

# %%
#df.loc[[0,1,2]]
#df.loc[1,"Loan_ID"]
#df.loc[0:3]
df.loc[5:9,["Loan_ID",'Gender','LoanAmount']]
df.iloc[:,[0,1,-1]].head()
# Out:
#     Loan_ID Gender        date
# 0  LP001002   Male  2021-03-16
# 1  LP001003   Male  2021-03-16
# 2  LP001005   Male  2021-03-16
# 3  LP001006   Male  2021-03-16
# 4  LP001008   Male  2021-03-16

# %%
df_rand = df.sample(n=20)
df_rand.head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 331  LP002098    Male      No          0      Graduate            No
# 281  LP001914    Male     Yes          0      Graduate            No
# 426  LP002367  Female      No          1  Not Graduate            No
# 201  LP001677    Male      No          2      Graduate            No
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 331             2935                0.0        98.0             360.0
# 281             3927              800.0       112.0             360.0
# 426             4606                0.0        81.0             360.0
# 201             4923                0.0       166.0             360.0
# 44              4695                0.0        96.0               NaN
#
#     Credit_History Property_Area Loan_Status        date
# 331            1.0     Semiurban           Y  2021-03-16
# ...

# %%
#df_rand.loc[[0,1,2]]
#df_rand.loc[1,"Loan_ID"]
df_rand.loc[331,"Loan_ID"]
#df_rand.loc[0:3]
# Out:
# 'LP002098'

# %%
#df_rand.iloc[[0,1,2]]
#df.iloc[1,"Loan_ID"]
df_rand.iloc[0:3]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 331  LP002098    Male      No          0      Graduate            No
# 281  LP001914    Male     Yes          0      Graduate            No
# 426  LP002367  Female      No          1  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 331             2935                0.0        98.0             360.0
# 281             3927              800.0       112.0             360.0
# 426             4606                0.0        81.0             360.0
#
#     Credit_History Property_Area Loan_Status        date
# 331            1.0     Semiurban           Y  2021-03-16
# 281            1.0     Semiurban           Y  2021-03-16
# 426            1.0         Rural           N  2021-03-16

# %%
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
df.Gender
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
df[['Gender','LoanAmount']].head()
# Out:
#   Gender  LoanAmount
# 0   Male         NaN
# 1   Male       128.0
# 2   Male        66.0
# 3   Male       120.0
# 4   Male       141.0

# %%
df[df["Gender"] == 'Male'].shape
# Out:
# (489, 14)

# %%
df.sort_values(by="LoanAmount",ascending=False,inplace=False)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 155  LP001536    Male     Yes         3+      Graduate            No
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 369  LP002191    Male     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 479  LP002533    Male     Yes          2      Graduate            No
# 524  LP002697    Male      No          0      Graduate            No
# 550  LP002778    Male     Yes          2      Graduate           Yes
# 551  LP002784    Male     Yes          1  Not Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.sort_values(by=["LoanAmount",'ApplicantIncome'], ascending=[True, False],inplace=False)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 568  LP002840  Female      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# 94   LP001325    Male      No          0  Not Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 555  LP002792    Male     Yes          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 81   LP001266    Male     Yes          1      Graduate           Yes
# 35   LP001106    Male     Yes          0      Graduate            No
# 437  LP002401    Male     Yes          0      Graduate            No
# 305  LP001990    Male      No          0  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## Normalizacion via Z-score( (x- mean)/std)

# %%
mean_loan=df['LoanAmount'].mean()
mean_loan
# Out:
# 146.41216216216216

# %%
std_loan=df['LoanAmount'].std()
std_loan
# Out:
# 85.58732523570545

# %%
df['zscoreloanamount']=(df['LoanAmount']-mean_loan)/std_loan
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#   Credit_History Property_Area Loan_Status        date  zscoreloanamount
# 0            1.0         Urban           Y  2021-03-16               NaN
# ...

# %% [markdown]
# ### Normalizacion via (x -min)/(max -min)

# %%
min_loan=df['LoanAmount'].min()
max_loan=df['LoanAmount'].max()
df['minmaxLoanAmount']=(df['LoanAmount']-min_loan)/(max_loan-min_loan)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#   Credit_History Property_Area Loan_Status        date  zscoreloanamount  \
# 0            1.0         Urban           Y  2021-03-16               NaN
# ...

# %%
df['Property_Area'].unique()

# # urban=0  ; rural=1; semiurban=2
# # urban_ind=0  ; rural_ind=1; semiurban_ind=2
# urban              1 0 0    
# urban              1 0 0
# rural              0 1 0
# semiurban          0 0 1
# rural              0 1 0
        
# # urban_ind=0  ; rural_ind=1
# urban              1 0     
# urban              1 0 
# rural              0 1 
# semiurban          0 0 
# rural              0 1
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
Property_Area_1hot = pd.get_dummies(df['Property_Area'], drop_first=True)

# %%
Property_Area_1hot
# Out:
#      Semiurban  Urban
# 0        False   True
# 1        False  False
# 2        False   True
# 3        False   True
# 4        False   True
# ..         ...    ...
# 609      False  False
# 610      False  False
# 611      False   True
# 612      False   True
# 613       True  False
#
# [614 rows x 2 columns]

# %%
#tranformaciones features pd

df['LoanAmountcross']= df['LoanAmount']*df['Loan_Amount_Term']

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
def extract_year(x):
    y= x['date']
    year=y.year
    return year
df['year']= df.apply(lambda x : extract_year(x),axis=1)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#   Credit_History Property_Area Loan_Status       date  zscoreloanamount  \
# 0            1.0         Urban           Y 2021-03-16               NaN
# ...

# %%
df.groupby('Gender')['ApplicantIncome'].sum()
# Out:
# Gender
# Female     520069
# Male      2663319
# Name: ApplicantIncome, dtype: int32

# %%
df.groupby(['Gender','Education'])['ApplicantIncome'].sum()
# Out:
# Gender  Education
# Female  Graduate         427475
#         Not Graduate      92594
# Male    Graduate        2253122
#         Not Graduate     410197
# Name: ApplicantIncome, dtype: int32

# %%
df.plot.scatter(x='ApplicantIncome',y='LoanAmount')
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
df.hist(column='ApplicantIncome',bins=25, grid=False, figsize=(8,5), color='#86bf91', zorder=2, rwidth=0.9)
# Out:
# array([[<Axes: title={'center': 'ApplicantIncome'}>]], dtype=object)

# %%
from matplotlib.ticker import StrMethodFormatter
ax = df.hist(column='ApplicantIncome', by='Gender', bins=25, grid=False, figsize=(8,10), layout=(3,1), sharex=True, color='#86bf91', zorder=2, rwidth=0.9)

for i,x in enumerate(ax):

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Set x-axis label
    x.set_xlabel("Session Duration (Seconds)", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    if i == 1:
        x.set_ylabel("Sessions", labelpad=50, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

    x.tick_params(axis='x', rotation=0)

# %% [markdown]
# ## pygwalker:
# PyGWalker contiene una potente tabla de datos, que proporciona una vista rápida de los datos y su distribución, perfilado

# %%
#!pip install pygwalker --upgrade

# %%
import pandas as pd
import pygwalker as pyg

# %%
walker = walker = pyg.walk(
    df_exl,
    #spec="chart_meta_0.json",    # this json file will save your chart state, you need to click save button in ui mannual when you finish a chart, 'autosave' will be supported in the future.
    kernel_computation=False,          # set `kernel_computation=True`, pygwalker will use duckdb as computing engine, it support you explore bigger dataset(<=100GB).
)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000621d92fb72af6pLFMDyVC7GOB2kat" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000621d92fb72af6pLFMDyVC7GOB2kat") {
#             var iframe = document.getElementById("gwalker-000621d92fb72af6pLFMDyVC7GOB2kat");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
df_exl
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2021-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2021-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2021-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2021-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2021-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2021-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2021-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2021-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2021-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2021-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2021-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2021-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2021-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
import geopandas as gpd
import pandas as pd

# %%
#!conda install --channel conda-forge geopandas

# %%
url = "https://www.datos.gov.co/resource/9vha-vh9n.geojson"
hurtos_colombia = gpd.read_file(url)
hurtos_colombia = hurtos_colombia.set_index("codigo_dane")
hurtos_colombia
# Out:
#                 genero          municipio fecha_hecho cantidad  \
# codigo_dane
# 05001000     NO APLICA      MEDELLÍN (CT)   1/01/2010        1
# 05212000     NO APLICA         COPACABANA   1/01/2010        1
# 05001000     NO APLICA      MEDELLÍN (CT)   1/01/2010        1
# 11001000     NO APLICA   BOGOTÁ D.C. (CT)   1/01/2010        1
# 76001000     NO APLICA          CALI (CT)   1/01/2010        1
# ...                ...                ...         ...      ...
# 11001000     NO APLICA   BOGOTÁ D.C. (CT)   9/03/2010        4
# 52001000     NO APLICA         PASTO (CT)   9/03/2010        1
# 76001000     NO APLICA          CALI (CT)   9/03/2010        2
# 54001000     NO APLICA        CÚCUTA (CT)   9/03/2010        1
# 08001000     NO APLICA  BARRANQUILLA (CT)   9/03/2010        1
#
#                  tipo_de_hurto   armas_medios grupo_etario  \
# codigo_dane
# 05001000     HURTO AUTOMOTORES  ARMA DE FUEGO    NO APLICA
# 05212000     HURTO AUTOMOTORES  LLAVE MAESTRA    NO APLICA
# ...

# %%
hurtos_colombia.isnull().sum()
# Out:
# genero              0
# municipio           0
# fecha_hecho         0
# cantidad            0
# tipo_de_hurto       0
# armas_medios        0
# grupo_etario        0
# departamento        0
# geometry         1000
# dtype: int64

# %%
municipios = gpd.read_file(r"COL_Municipio.zip")
municipios = municipios.set_index("cod_dane")
municipios
# Out:
#              ID  TOTPOP_CY    Shape__Are    Shape__Len  \
# cod_dane
# 05001000  05001    2559097  3.798647e+08  1.072579e+05
# 05002000  05002      20493  5.155810e+08  1.282157e+05
# 05004000  05004       2763  2.935562e+08  8.885140e+04
# 05021000  05021       4746  1.294922e+08  7.572552e+04
# 05030000  05030      31600  8.456353e+07  5.066772e+04
# ...         ...        ...           ...           ...
# 97889000  97889       1108  4.669929e+09  4.292950e+05
# 99001000  99001      20500  1.234376e+10  6.149489e+05
# 99524000  99524       9705  1.844082e+10  8.362720e+05
# 99624000  99624       4235  3.992354e+09  3.642825e+05
# 99773000  99773      79662  6.595269e+10  2.070641e+06
#
#                                                    geometry
# cod_dane
# 05001000  POLYGON ((-8423087.868 710530.773, -8423036.11...
# 05002000  POLYGON ((-8400992.107 663049.702, -8400902.90...
# 05004000  POLYGON ((-8469712.412 753218.991, -8469679.34...
# ...

# %%
municipios  = municipios.to_crs("EPSG:4326")
municipios
# Out:
#              ID  TOTPOP_CY    Shape__Are    Shape__Len  \
# cod_dane
# 05001000  05001    2559097  3.798647e+08  1.072579e+05
# 05002000  05002      20493  5.155810e+08  1.282157e+05
# 05004000  05004       2763  2.935562e+08  8.885140e+04
# 05021000  05021       4746  1.294922e+08  7.572552e+04
# 05030000  05030      31600  8.456353e+07  5.066772e+04
# ...         ...        ...           ...           ...
# 97889000  97889       1108  4.669929e+09  4.292950e+05
# 99001000  99001      20500  1.234376e+10  6.149489e+05
# 99524000  99524       9705  1.844082e+10  8.362720e+05
# 99624000  99624       4235  3.992354e+09  3.642825e+05
# 99773000  99773      79662  6.595269e+10  2.070641e+06
#
#                                                    geometry
# cod_dane
# 05001000  POLYGON ((-75.66589 6.36965, -75.66542 6.36866...
# 05002000  POLYGON ((-75.46740 5.94558, -75.46659 5.94444...
# 05004000  POLYGON ((-76.08472 6.75061, -76.08442 6.75049...
# ...

# %%
test = municipios.merge(hurtos_colombia_agrupados, left_on='cod_dane', right_on='codigo_dane')
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 test = municipios.merge(hurtos_colombia_agrupados, left_on='cod_dane', right_on='codigo_dane')
#       2 test
#
# NameError: name 'hurtos_colombia_agrupados' is not defined

# %%
axis = municipios.plot(figsize = (20, 12))
test.plot(column = "count", ax = axis, legend = True)
# Out:
# c:\Users\javier\miniconda3\envs\clase1\lib\site-packages\geopandas\plotting.py:48: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:
# c:\Users\javier\miniconda3\envs\clase1\lib\site-packages\geopandas\plotting.py:48: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:
# <Axes: >

# %%
test = municipios.merge(hurtos_colombia, left_on='cod_dane', right_on='codigo_dane')
test
# Out:
#         ID  TOTPOP_CY    Shape__Are     Shape__Len  \
# 0    05001    2559097  3.798647e+08  107257.930213
# 1    05001    2559097  3.798647e+08  107257.930213
# 2    05001    2559097  3.798647e+08  107257.930213
# 3    05001    2559097  3.798647e+08  107257.930213
# 4    05001    2559097  3.798647e+08  107257.930213
# ..     ...        ...           ...            ...
# 995  85001     179489  2.520565e+09  340545.621006
# 996  85410      25428  2.419753e+09  463096.658534
# 997  85410      25428  2.419753e+09  463096.658534
# 998  85410      25428  2.419753e+09  463096.658534
# 999  86568      67892  2.831324e+09  399185.645364
#
#                                             geometry_x     genero  \
# 0    POLYGON ((-75.66589 6.36965, -75.66542 6.36866...  NO APLICA
# 1    POLYGON ((-75.66589 6.36965, -75.66542 6.36866...  NO APLICA
# 2    POLYGON ((-75.66589 6.36965, -75.66542 6.36866...  NO APLICA
# 3    POLYGON ((-75.66589 6.36965, -75.66542 6.36866...  NO APLICA
# ...

# %%
def generate_long_lat(x1):
    lon=x1.geometry_x.centroid.x
    lat=x1.geometry_x.centroid.y
    return lon, lat

test[['longitude','latitude']]= test.apply(lambda x: generate_long_lat(x),axis=1,result_type='expand')

# %%
test_1 = pd.DataFrame(test)
test_1.drop(columns='geometry_x',inplace=True)
test_1.drop(columns='geometry_y',inplace=True)

# %%
walker =  pyg.walk(test_1)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000621d932db1d67bUs3Qu6j1APhdcnk" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000621d932db1d67bUs3Qu6j1APhdcnk") {
#             var iframe = document.getElementById("gwalker-000621d932db1d67bUs3Qu6j1APhdcnk");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %% [markdown]
# # Dask:
# - Dask es una biblioteca de computación paralela flexible para computación analítica escrita en Python.

# %%
#!python -m pip install dask

# %%
import dask.dataframe as dd

# %% [markdown]
# - urlpathstring or list
#
#     - Absolute or relative filepath(s). Prefix with a protocol like s3:// to read from alternative filesystems. To read from multiple files you can pass a globstring or a list of paths, with the caveat that they must all have the same protocol.
# - blocksizestr, int or None, optional
#
#     - Number of bytes by which to cut up larger files. Default value is computed based on available physical memory and the number of cores, up to a maximum of 64MB. Can be a number like 64000000 or a string like "64MB". If None, a single block is used for each file

# %%
dff = dd.read_csv('loan_data_set.csv',blocksize=20e3)#20Kb #def. 25e6 25MB

# %%
#numero de particiones
dff.npartitions
# Out:
# 2

# %%
## ver el dataframe
dff.compute()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 302  LP002978  Female      No          0      Graduate            No
# 303  LP002979    Male     Yes         3+      Graduate            No
# 304  LP002983    Male     Yes          1      Graduate            No
# 305  LP002984    Male     Yes          2      Graduate            No
# 306  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dff.shape # lazy eval.
# Out:
# (Delayed('int-4c8b45ba-435c-4f1d-a597-84dbffd04bc5'), 14)

# %%
dff.dtypes
# Out:
# Loan_ID              string[pyarrow]
# Gender               string[pyarrow]
# Married              string[pyarrow]
# Dependents           string[pyarrow]
# Education            string[pyarrow]
# Self_Employed        string[pyarrow]
# ApplicantIncome                int64
# CoapplicantIncome            float64
# LoanAmount                   float64
# Loan_Amount_Term             float64
# Credit_History               float64
# Property_Area        string[pyarrow]
# Loan_Status          string[pyarrow]
# date                 string[pyarrow]
# dtype: object

# %%
dff.notnull().sum().compute()
# Out:
# Loan_ID              614
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# date                 614
# dtype: int64

# %%
dff.describe().compute()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2961.500000           0.000000  100.000000         360.00000
# 50%        3858.000000        1250.000000  128.000000         360.00000
# 75%        5970.500000        2317.500000  172.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
dff['ApplicantIncome'].max(axis = 0).compute()
# Out:
# 81000

# %%
dff.groupby(by = 'Gender')['ApplicantIncome'].mean().compute()
# Out:
# Gender
# Female    4643.473214
# Male      5446.460123
# Name: ApplicantIncome, dtype: float64

# %%
iter_csv = pd.read_csv(
    "loan_data_set.csv",
    iterator=True,
    chunksize=100
)

# %%
for chunk in iter_csv:
    print(chunk.shape)

# %%
chunk
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 600  LP002949  Female      No         3+      Graduate           NaN
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 602  LP002953    Male     Yes         3+      Graduate            No
# 603  LP002958    Male      No          0      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# ...

# %%
df_iter = pd.concat(chunks for chunks in iter_csv)
df_iter
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
